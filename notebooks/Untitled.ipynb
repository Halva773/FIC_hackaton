# %% [raw]
# !pip install --upgrade rapidfuzz

# %%
# !python --version
# Out:
# Python 3.11.5

# %%
import pandas as pd
import re
from collections import defaultdict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import json
from datetime import datetime
from dateutil.relativedelta import relativedelta
import pymorphy3
from rapidfuzz import process, fuzz

# %%
def clean_and_reduce_skills(data, column_name='key_skills', threshold=80):
    """
    Очищает, нормализует и сокращает количество уникальных навыков в указанном столбце.
    
    Параметры:
        data (pd.DataFrame): Исходный DataFrame.
        column_name (str): Название столбца с навыками.
        threshold (int): Порог для объединения похожих навыков (0-100).
    
    Возвращает:
        list: Отсортированный и уменьшенный список уникальных навыков.
    """
    # Шаг 1: Удаляем пропущенные значения и разделяем навыки
    all_skills = data[column_name].dropna().str.split(',').sum()
    
    # Шаг 2: Приводим к нижнему регистру и удаляем лишние пробелы
    cleaned_skills = {skill.strip().lower() for skill in all_skills if skill.strip()}
    
    # Шаг 3: Объединяем похожие навыки
    reduced_skills = []
    while cleaned_skills:
        skill = cleaned_skills.pop()
        similar_skills = process.extract(skill, cleaned_skills, scorer=fuzz.ratio, score_cutoff=threshold)
        reduced_skills.append(skill)
        # Удаляем все найденные похожие навыки
        for match, _, _ in similar_skills:
            cleaned_skills.discard(match)
    
    # Шаг 4: Сортируем результат
    return sorted(reduced_skills)

# %%
def normalize_russian_words(words):
    """
    Приводит русский текст к нормальной форме.
    """
    morph = pymorphy3.MorphAnalyzer()
    return [morph.parse(word)[0].normal_form for word in words]

def add_features_to_dataframe(data, features, skills_column='key_skills'):
    """
    Добавляет столбцы для признаков и отмечает их наличие в ключевых навыках.

    Параметры:
        data (pd.DataFrame): Исходный DataFrame.
        features (list): Список признаков.
        skills_column (str): Название столбца с ключевыми навыками.

    Возвращает:
        pd.DataFrame: DataFrame с добавленными столбцами признаков.
    """
    # Удаляем дубликаты из списка признаков
    features = list(set(features))
    
    # Отделяем русские слова от остальных
    russian_words = [feature for feature in features if re.search(r'[а-яА-Я]', feature)]
    other_words = [feature for feature in features if feature not in russian_words]
    
    # Нормализуем русские слова
    normalized_russian_words = normalize_russian_words(russian_words)
    
    # Объединяем нормализованные русские слова с другими
    final_features = normalized_russian_words + other_words

    # Добавляем столбцы с признаками
    for feature in final_features:
        data[feature] = 0  # Инициализация столбцов с нулями
    
    morph = pymorphy3.MorphAnalyzer()

    # Проверяем навыки в key_skills построчно
    for index, row in data.iterrows():
        key_skills = str(row[skills_column]).lower().replace(' ', '_').replace('-', '_').split(', ')
        for feature in final_features:
            if feature in key_skills:
                f = morph.parse(feature)[0].normal_form
                print(f)
                data.loc[index, f] = 1  # Помечаем 1, если навык найден

    return data

# %%
with open("../data/client_dataset.json", "r", encoding="utf-8") as file:
    data = json.load(file)
    
data = pd.DataFrame(data)

# %%
clean_and_reduce_skills(data)
# Out:
# ['!с: erp',
#  '#c',
#  '(elk',
#  '(java 8 (java-core',
#  '(jpa',
#  '(mockups',
#  '(n)hibernate',
#  '(opensearch managed)',
#  '(vipnet',
#  '(web flux',
#  '(линейная/логистическая',
#  ')',
#  '* client server ios application * ble communication with central peripheral architecture * cardfli',
#  '* быстрый и способный внедрять новые передовые технологии',
#  '* глубоком знании всех компонентов android: фрагментов',
#  '* ключевой разработчик android',
#  '* мониторинге стабильности приложений',
#  '* обзор кода',
#  '* охват тестированием',
#  '* последовательность в выполнении работы в срок',
#  '* производительности и настройке приложений (jvm / android)',
#  '* разработка приложений',
#  '* разработке нативного android',
#  '* разработчик android java/kotlin',
#  '* рефакторинг и редизайн существующих функций',
#  '* страсть к технологиям и разработке программного обеспечения',
#  '*nix',
#  '*nix services: apache',
#  '+c4',
#  '- always understand other people or quickly clarify if there is a misunderstanding between my vision and',
#  '- api tests (rest and grpc)',
#  '- automation and grow to sdet',
#  '- backend testing and business logic',
#  '- basic skills of automation with node.js+typescript+jest (api tests rest and grpc)',
#  '- basic skills of unix terminal and bash scripts',
#  '- communicable',
#  '- english b1 (reading of tech documentation',
#  '- experience in mocking external services for staging stand',
#  '- expirience in work with rabbitmq',
#  '- functional',
#  '- good analytic skills(like bug localization and asking right questions for requirements clarification)',
#  '- grow as an analyst',
#  '- implemented benchmarking and load tests',
#  '- intellij idea',
#  '- introduced continuous software delivery process',
#  '- js\n- react\n- redux',
#  '- junit',
#  '- knowledge in techniques of test design',
#  '- linux системы',
#  '- little experience in perfomance',
#  '- lombok',
#  '- make things around me work better',
#  '- maven',
#  '- moved codebase from javascript to typescript',
#  '- nginx',
#  '- postman',
#  '- reduced aws costs in 40%',
#  '- reduced manual testing in 20%',
#  '- restful',
#  '- rsocket',
#  '- sanity',
#  '- sniffing and analysing of traffic by fiddler',
#  '- spring 5+ (spring data jpa',
#  '- sql (made a lot of data reports for my team)',
#  '- sql - mysql',
#  '- swagger (openapi)',
#  '- taught the team how to write unit and integration tests',
#  '- understanding of bdd conception',
#  '- understanding of microservice architecture and a lot of practice in testing it (i have tested a whole',
#  '- understanding of network technologies( course of network technologies from university + half part of',
#  '- vernemq',
#  '- working with ci/cd pipline',
#  '- working with data',
#  '- встраиваемое по',
#  '- дизайн: figma. умею работать с components',
#  '- комплексный взгляд на системы и решения',
#  '- языки программирования (в порядке убывания владения): c',
#  '-19',
#  '.',
#  '. net',
#  '. управление разработкой',
#  '...)',
#  '.net (asp',
#  '.net 4.6.1',
#  '.net 5-7',
#  '.net 5.0',
#  '.net 5/6',
#  '.net 6 wpf',
#  '.net 7.0-8.0',
#  '.net 8',
#  '.net c#',
#  '.net core 1.1',
#  '.net core 2.2-8',
#  '.net core 2/3',
#  '.net core api',
#  '.net core microservices',
#  '.net core mvc',
#  '.net framework 2.0 - 4.8',
#  '.net framework 4.5-4.7.1',
#  '.net framework core',
#  '.net framework/.net core/.net',
#  '.net vb',
#  '.netcore',
#  '004',
#  '01',
#  '02',
#  '08',
#  '1',
#  '1 с',
#  '10 лет опыта работы в области финансов и информационных технологий;',
#  '10 лет успешного опыта удаленной работы',
#  '10)',
#  '10g',
#  '11',
#  '126 фз',
#  '12c',
#  '149 фз',
#  '15)',
#  '152',
#  '152фз',
#  '152фз pcidss cisco кии 187фз гост 57580',
#  '16 (cads 6)',
#  '161-фз',
#  '17',
#  '17-фстэк',
#  '187 фз',
#  '19011',
#  '1c appius-plm',
#  '1c bitrix',
#  '1c-bitrix / umi.cms',
#  '1c-предприятие',
#  '1c.',
#  '1c82',
#  '1c: enterprise resource planning',
#  '1c: erp',
#  '1c: erp проф',
#  '1c: бухгалтерия 8 (редакция 3.0)',
#  '1c: финансы',
#  '1c:enterprise',
#  '1c:erp\r\n•\tметодологии работы: agile',
#  '1c:erp управление предприятием 2',
#  '1с 7.7/8.1/8.2',
#  '1с 8.3',
#  '1с 8.3 предприятие',
#  '1с : унф',
#  '1с erp',
#  '1с erp oracle моделирование процессов big data hadoop python java sql unit testing ms sql',
#  '1с erp управление холдингом',
#  '1с fresh',
#  '1с wms',
#  '1с аналитика 1с программирование 1с:зуп  1с:уп',
#  '1с апк',
#  '1с бгу',
#  '1с бухгалтерия версия 7.7.',
#  '1с внесение изменений и дополнений',
#  '1с доработка существующего функционала',
#  '1с запросы',
#  '1с конвертация данных',
#  '1с корпоративная информационная система',
#  '1с мдм',
#  '1с мфо и кпк',
#  '1с предприятие 8.3',
#  '1с предприятие комплексная версия 8.2',
#  '1с программирование 1с: предприятие 8  1с: бухгалтерия  1с: зарплата и управление персоналом  обновление конфигурации 1с  управление проектами  ms sql server  1с: документооборот  администрирование сетевого оборудования',
#  '1с проектирование и разработка новых программных модулей',
#  '1с разработка внешних обработок',
#  '1с разработка и реализация обменов (интеграции) со сторонними программными продуктами (прим. web-',
#  '1с разработка конфигураций',
#  '1с разработка модулей',
#  '1с сппр',
#  '1с упп',
#  '1с ут',
#  '1с( версии 7.7.',
#  '1с- асу ид',
#  '1с-битрикс',
#  '1с.',
#  '1с.унф',
#  '1с: crm 3',
#  '1с: crm проф',
#  '1с: битфинанс',
#  '1с: бсп',
#  '1с: бухгалтерия и склад',
#  '1с: бухгалтерия предприятия',
#  '1с: бухгалтерия проф',
#  '1с: ерпух',
#  '1с: зарплата и кадры',
#  '1с: зарплата и управление персоналом',
#  '1с: зуп',
#  '1с: зуп 3.1',
#  '1с: инвеста',
#  '1с: консолидация',
#  '1с: предприятие работа в команде  1с: бухгалтерия  1с программирование  1с: управление торговлей  1с: розница  пользователь пк  обновление конфигурации 1с',
#  '1с: предприятие управление страховой компанией',
#  '1с: предприятие: бухгалтерский учет',
#  '1с: предприятие: розница',
#  '1с: производство',
#  '1с: розница',
#  '1с: склад',
#  '1с: тоир',
#  '1с: торговля',
#  '1с: торговля и склад',
#  '1с: управление автотранспортом',
#  '1с: управление небольшой фирмой',
#  '1с: управление производственным предприятием',
#  '1с: управление торговлей',
#  '1с: управление торговлей technical design nosql it transformatrion',
#  '1с: усц.',
#  '1с:pdm',
#  '1с:wms логистика управление складом.',
#  '1с:библиотека стандартных подсистем',
#  '1с:бухгалтерия государственного учреждения',
#  '1с:комплексная автоматизация 8.',
#  '1с:рт.',
#  '1с:умфоикпк',
#  '1с:утап',
#  '2',
#  '2-я линия техподдержки',
#  '2.105',
#  '20',
#  '2008',
#  '2009',
#  '2012',
#  '2014',
#  '2017',
#  '218-фз',
#  '223 фз',
#  '235',
#  '236',
#  '237',
#  '24xx',
#  '27005',
#  '28хх',
#  '2900',
#  '2960',
#  '2gis',
#  '2gis sdkgit',
#  '3 года производственного опыта в разработке программного обеспечения (мобильная разработка).',
#  '3 группа по электробезопасности',
#  '3 фаза клинических исследований',
#  '3)',
#  '3.x',
#  '31',
#  '33xx',
#  '34',
#  '34 гост',
#  '3500',
#  '3560',
#  '3700',
#  '3750(vlan',
#  '37хх',
#  '390 фз',
#  '3com',
#  '3cx;\r\nstandards',
#  '3d',
#  '3d max',
#  '3d secure',
#  '3d моделирование',
#  '3d-графика',
#  '3d-печать',
#  '3ds server',
#  '3gpp',
#  '3nf',
#  '3par',
#  '3utools',
#  '4/1',
#  '44',
#  '44 фз',
#  '45',
#  '4500 series',
#  '45xx',
#  '5',
#  '5 / xcode / dart / swiftui • mvc / mvvm / mvp • coredata/ realm / gcd / gesture recognizers/ segues/ animations/arc • uikit / protocols',
#  '5 и cucumber; работа со сборщиками проектов maven и gradle; работа с инструментами разработки: jira',
#  '5+ years of experience in wide stack of the .net technologies',
#  '5/3.1',
#  '50',
#  '51',
#  '53xx',
#  '57580',
#  '57xx; eltex: настройка и администрирование коммутаторов mes23xx',
#  '5f',
#  '5g',
#  '6',
#  '6 sigma',
#  '6+) / typescript',
#  '60',
#  '62',
#  '63-фз',
#  '63; подзаконные акты фстэк и фсб.',
#  '65хх)',
#  '66 (67).',
#  '7',
#  '7.x',
#  '716-п',
#  '72xx',
#  '757-п',
#  '76',
#  '76хх',
#  '8',
#  '8-11',
#  '8.1',
#  '8.2',
#  '8.3',
#  '8.хх)',
#  '800',
#  '802.1x',
#  '9',
#  '9.40)',
#  '90',
#  '9000',
#  '91',
#  '97',
#  '98 фз',
#  '999',
#  ': python',
#  'a/b',
#  'a/b experiments',
#  'a/b testing: optimizely',
#  'a/b tests',
#  'a/b-тестирование',
#  'a/b-тесты',
#  'a11y',
#  'aallure',
#  'aarrr-метрики',
#  'ab initio',
#  'abac',
#  'abap',
#  'abap 4 effort estimation',
#  'abbyy finereader',
#  'abc analysis',
#  'abc ibso',
#  'abcdx-сегментация',
#  'ability to handle large volumes of work',
#  'ableton live',
#  'abstract.',
#  'ac wfm',
#  'acca',
#  'acceptance criteria',
#  'access',
#  'access control',
#  'access-level',
#  'access-list)',
#  'accessibility',
#  'accessibility testing  автоматизированное тестирование',
#  'accessibility тестирование.',
#  'accessibility.\r\nt-shaped skills: проектирование интерфейсов',
#  'accompanist(permissions',
#  'accomplishments\r\n- split a monolithic system into microservices',
#  'account management',
#  'accuracy',
#  'acl',
#  'acquiring',
#  'acra',
#  'acronis',
#  'acronis cyber cloud (150+ макро/микро сервисов)',
#  'active /rabbit/zeromq',
#  'active data guard',
#  'activecollab',
#  'active\xa0directory windows\xa0server\xa02003  администрирование\xa0серверов\xa0windows  vmware  ms\xa0sql\xa0server  ms\xa0exchange\xa0server  ms\xa0sql  windows\xa0server\xa02008\xa0r2  directum  windows\xa07  oracle  электронный\xa0документооборот  ms\xa0exchange  сэд  настройка\xa0почтовых\xa0серверов  резервное\xa0копирование  работа\xa0с\xa0базами\xa0данных  администрирование  cистемы\xa0управления\xa0базами\xa0данных  база\xa0данных:\xa0oracle  системное\xa0администрирование  базы\xa0данных  выездное\xa0обслуживание  windows\xa0vista  windows\xa0os  системное\xa0мышление  ms\xa0dos  оперативный\xa0поиск\xa0информации\xa0в\xa0сети\xa0интернет  умение\xa0расставлять\xa0приоритеты  организационные\xa0навыки',
#  'activiti bpm',
#  'activity diagram',
#  'activitykit',
#  'activitymq.',
#  'activmq',
#  'actix',
#  'actuator',
#  'acunetix',
#  'ad hoc testing',
#  'ad-hoc отчет',
#  'adalo',
#  'adaptavist test management',
#  'adaptavista',
#  'adapter',
#  'adaptive layout',
#  'adaptive web',
#  'adapty',
#  'adf',
#  'adfox',
#  'adfs 3.0',
#  'adjust',
#  'administered windows',
#  'administrating skills',
#  'administration',
#  'administrative support',
#  'admob',
#  'admt',
#  'adnroid',
#  'ado',
#  'ado.net',
#  'ado.net entity framewor',
#  'adobe acrobat',
#  'adobe acrobat distiller',
#  'adobe acrobat pro dc',
#  'adobe after effect',
#  'adobe analytics',
#  'adobe animate',
#  'adobe audition',
#  'adobe creative suite 2',
#  'adobe cs',
#  'adobe flash',
#  'adobe flexicapture',
#  'adobe illustrator',
#  'adobe illustrator.\r\nвеб и мобильный ux/ui',
#  'adobe indesign',
#  'adobe lightroom',
#  'adobe photoshop.',
#  'adobe premier',
#  'adobe script)',
#  'adobe xd',
#  'adr',
#  'ads',
#  'ads libraries',
#  'ads manager',
#  'advanced analytics',
#  'advanced/fluent english',
#  'advanta',
#  'adventnet netflowanalyzer',
#  'adventnet opmanager',
#  'advertising',
#  'advising people',
#  'aem/day cq',
#  'aerospike',
#  'affiliate marketing',
#  'affinity designer',
#  'afnetworking',
#  'afs',
#  'after effects',
#  'after effects) и figma',
#  'aftereffect. midjourney',
#  'ag-grid',
#  'agail',
#  'agat',
#  'agentry',
#  'agile\r\ntools: figma',
#  'agile (scram',
#  'agile application development.',
#  'agile dev',
#  'agile mindset',
#  'agile safe',
#  'agile sql gradle dwh etl',
#  'agile testing',
#  'agile трансформация',
#  'agile-менеджмент',
#  'agile-управление',
#  'agile.',
#  'agile/scrum',
#  'aglie methodologies',
#  'agora',
#  'ahk',
#  'ai optaplanner',
#  'ai-сервисы',
#  'aidbox',
#  'aidl',
#  'aidl interfaces',
#  'aiocache',
#  'aiogram',
#  'aiohttp',
#  'aiohttp fastapi',
#  'aiokafka',
#  'airbyte',
#  'aircrack',
#  'airdump',
#  'airflow(dags)',
#  'airflow.',
#  'airgeddon',
#  'airmon',
#  'airpush',
#  'airtable',
#  'airtest',
#  'aix',
#  'aja bridge live',
#  'ajax',
#  'ajax swing',
#  'ajile',
#  'akita',
#  'akka',
#  'akka (http',
#  'akka (java api)',
#  'akka-http/spray',
#  'akka.net',
#  'akka.net (actors)',
#  'akmaskfield',
#  'aladdin',
#  'aladdin jacarta authentication system',
#  'aladdin jacarta management system',
#  'alarm centre',
#  'alc',
#  'ald pro',
#  'alembic',
#  'alertmanager zabbix.',
#  'alertmanager;\r\nсубд: mysql',
#  'alerts',
#  'alfresco',
#  'algolia',
#  'algorithm development',
#  'algorithms and data structures',
#  'algorithms.',
#  'alice incpector',
#  'all the current apps are developed with modular architecture',
#  'all-ip.',
#  'allfusion erwin data modeler',
#  'allfusion process modeler',
#  'alliance access',
#  'allure contacts:',
#  'allure testops',
#  'alpaca',
#  'alpakka',
#  'alpine linux',
#  'alpinejs',
#  'alt linux',
#  'altair',
#  'alteryx',
#  'altium designer',
#  'altova',
#  'altova products',
#  'altova xmlspy.',
#  'amadeus',
#  'amazom',
#  'amazon aws (ec2)',
#  'amazon aws (sqs',
#  'amazon aws framework',
#  'amazon cognito',
#  'amazon dynamodb',
#  'amazon ec2',
#  'amazon rds',
#  'amazon simple queue service',
#  'amazon web services',
#  'ambari',
#  'amdocs announces clarifycrm',
#  'amdocs crm',
#  'aml',
#  'amocrm',
#  'amp',
#  'amphp',
#  'amplitude',
#  'amplitude - визуализация данных',
#  'amplitude analytics',
#  'amplitude foundation',
#  'ampq rabbit mq',
#  'amps (broker)',
#  'amq',
#  'amqp(rabbitmq)',
#  'amqp)',
#  'anaconda',
#  'analysis for ms office',
#  'analysis service',
#  'analyst',
#  'analytical skills',
#  'analytics',
#  'analytics: yandex',
#  'anaplan',
#  'anchor modeling',
#  'anchors',
#  'and communication a bit)',
#  'and other;\r\nos/platforms: fortios',
#  'android and libraries: android sdk',
#  'android android sdk  sqlite  realm  git  kotlin  firebase  java  mvp  clean architecture  mvvm  mvc  dialogflow  rxjava  retrofit  koin  okhttp  google maps api  jetpack',
#  'android annotations',
#  'android architecture component',
#  'android billing library',
#  'android canvas api',
#  'android core',
#  'android debug bridge (adb)',
#  'android debugging',
#  'android design patterns',
#  'android development',
#  'android features: notifications',
#  'android in-app billing',
#  'android jetpack',
#  'android jetpack (view binding',
#  'android jetpack components',
#  'android kotlin',
#  'android lifecycle',
#  'android lifecycle architecture',
#  'android sdk',
#  'android sdk 19 - 21+',
#  'android sdk(view components)',
#  'android testing',
#  'android ui',
#  'android user interface guidelines',
#  'android(activity',
#  'android(немного)',
#  'android.',
#  'androidnavigation',
#  'androidstodio',
#  'androidwear',
#  'androin adb',
#  'angula 6',
#  'angular cli',
#  'angular js',
#  'angular material',
#  'angular2/4',
#  'angularjs 1.5',
#  'angurar',
#  'anhular',
#  'animate',
#  'animatedtransitioning',
#  'anka cloud',
#  'anko',
#  'anova',
#  'anpqp',
#  'ansi c++',
#  'ansi sql',
#  'ansible',
#  'ansible (playbooks etc)',
#  'ansible aws.',
#  'ansible openshift',
#  'ansible playbook. есть опыт работы с работы с tarantool',
#  'ansible/awx',
#  'ansys',
#  'ansys fluent',
#  'ansys products',
#  'ansys scade',
#  'ant.',
#  'antd',
#  'antdesign',
#  'antenna magus',
#  'anthill',
#  'anti-fraud',
#  'antivirus',
#  'antlr',
#  'anvil',
#  'anyconnect',
#  'anydesk.',
#  'anylogic',
#  'anylogic (simulation modeling)',
#  'aodocs',
#  'aop ( aspect )',
#  'aop)',
#  'aosp',
#  'aot',
#  'ap rest',
#  'apa',
#  'apach karaf',
#  'apache activemq',
#  'apache activemq artemis',
#  'apache airfow',
#  'apache camelimdg',
#  'apache cassandra',
#  'apache commons mathematics',
#  'apache connect',
#  'apache cordova',
#  'apache cxf',
#  'apache drill',
#  'apache ds',
#  'apache geode',
#  'apache hadoop (hdfs',
#  'apache hive (hs2/hms)',
#  'apache hproxy ansible',
#  'apache http',
#  'apache http server.',
#  'apache httpclient',
#  'apache hue',
#  'apache ignite)',
#  'apache impala',
#  'apache jboss fuse 6',
#  'apache jenkins',
#  'apache jmeter',
#  'apache kafka streams',
#  'apache maven',
#  'apache maven apache kafka',
#  'apache maven hibernate orm spring framework jenkins json api rest',
#  'apache maven java ee apache tomcat',
#  'apache maven junit sql uml grails tdd solid grasp protobuf armeria apache kafka',
#  'apache nifi',
#  'apache oozie',
#  'apache pdfbox',
#  'apache phoenix',
#  'apache qpid broker',
#  'apache servicemix',
#  'apache sling',
#  'apache spark',
#  'apache storm',
#  'apache streaming',
#  'apache superset',
#  'apache synapse',
#  'apache tomcat 8',
#  'apache web server',
#  'apache wicket',
#  'apache zeppelin',
#  'apache zookeeper',
#  'apache.\r\nпочтовые системы: sendmail postfix exim.',
#  'apache\xa0kafka',
#  'apache\xa0poi',
#  'apb.io',
#  'apex',
#  'apexcharts.js',
#  'aph',
#  'api',
#  'api (rest/soap)',
#  'api (soap',
#  'api / rest-assured',
#  'api doc',
#  'api gateway',
#  'api gazepoint',
#  'api git sql python',
#  'api gson',
#  'api testing rest',
#  'api testing; manage different frameworks creation for automation testing; test strategy design; communication skills; sap',
#  'api vk',
#  'api автотесты',
#  'api интерфейсы',
#  'api(postman',
#  'api: rest api',
#  'apiship',
#  'apns',
#  'apollo',
#  'apollo graphql',
#  'apollo router',
#  'apollo-client',
#  'app distribution',
#  'app extensions',
#  'app servers: tomcat',
#  'appache',
#  'appannie',
#  'appcenter',
#  'appclip',
#  'appcode',
#  'appdynamics',
#  'appearance',
#  'appflyer',
#  'appfuse',
#  'apphude',
#  'appium',
#  'appium (windows)',
#  'appium / uiautomator2',
#  'appium redmine',
#  'appium(java + testng)/python+pythest',
#  'appkit',
#  'applanga',
#  'apple fairplay',
#  'apple maps',
#  'apple push notifications',
#  'apple swift',
#  'apple;\r\nadministration: windows server: ad',
#  'applepay',
#  'applet',
#  'application architector',
#  'application managment',
#  'application support',
#  'applications and services deployment',
#  'applocker',
#  'appmetrika',
#  'appnavigator',
#  'apps script',
#  'appsechub',
#  'appsflyer (+ purchase connector)',
#  'appstore',
#  'appstore connect',
#  'apru',
#  'aptly',
#  'aqa',
#  'aqa lead',
#  'ar ...)',
#  'arango',
#  'araxis merge',
#  'arc/mrc',
#  'arcanum',
#  'arcgis',
#  'arcgis server',
#  'arch',
#  'archie mate',
#  'architect',
#  'architectural patterns',
#  'architecture governance',
#  'architecture review',
#  'architecture: mvp',
#  'architectures: clean arch',
#  'archlinux',
#  'archunit',
#  'arcore (augmented images)',
#  'arcsight',
#  'arcsight logger',
#  'arduino',
#  'arduino;\r\nvendors: fortinet',
#  'arenadata database',
#  'arenadata.',
#  'argo workflows',
#  'argocd',
#  'argocd/flux',
#  'argouml',
#  'aris epc',
#  'arisexpress',
#  'arm',
#  'armdocs',
#  'armeria',
#  'arp',
#  'arquillian',
#  'arrow.kt framework',
#  'arrowkt',
#  'artemis mq',
#  'artemis(openmessaging)',
#  'articulate rise',
#  'artifactory',
#  'artificial intellegence',
#  'aruba.',
#  'as is and to be',
#  'as is/to be',
#  'as is/to be mapping',
#  'as-is и to-be',
#  'as/400',
#  'as5200)',
#  'as5350',
#  'asa',
#  'asa 5510(dmz',
#  'asa5516x(vpn-ipsec',
#  'asana.',
#  'asciidoc',
#  'aserisk',
#  'ashot',
#  'asic',
#  'asmx',
#  'asn.1',
#  'asp .net',
#  'asp.mvc',
#  'asp.net core',
#  'asp.net core 3.1 - 6.0',
#  'asp.net framework',
#  'asp.net html',
#  'asp.net mvc.',
#  'asp.net mvc/ asp.net core',
#  'asp.net mvc/web api',
#  'asp.net web forms',
#  'asp.net webservice',
#  'aspectj',
#  'aspose\r\nsql: ms sql server',
#  'aspx',
#  'asr',
#  'asr100x',
#  'asr9000',
#  'asr901); huawei: настройка и внедрение ip/mpls сервисов на оборудовании huawei atn910b/950',
#  'asr9k',
#  'assembler.',
#  'assembly',
#  'assertj',
#  'assetlibrary',
#  'asterisk ami',
#  'astm.',
#  'astra',
#  'astra linux directory',
#  'astra linux.',
#  'astra linux. docker',
#  'astra брест',
#  'astralinux 1.6/1.7',
#  'async',
#  'async programming',
#  'async python',
#  'async/await',
#  'asyncapi',
#  'asyncapi studio',
#  'asyncdisplaykit',
#  'asyncio-pytest',
#  'asyncio.',
#  'asyncio/aiohttp',
#  'ataccama',
#  'atc',
#  'atl',
#  'atlas cli',
#  'atlas.',
#  'atlassian',
#  'atlassian bamboo',
#  'atlassian bitbucket',
#  'atlassian confluence • scrum',
#  'atlassian confluence.',
#  'atlassian croud',
#  'atlassian crucible',
#  'atlassian full stack',
#  'atlassian jira (user)',
#  'atlassian jira и confluence',
#  'atlassian jira.',
#  'atlassian software tools',
#  'atlassian space.',
#  'atlassian trello',
#  'atlassian\xa0jira testrail\u2006 \u2006 functional\xa0testing\u2006 \u2006 sql\u2006 \u2006 networking\u2006 \u2006 html\u2006 \u2006 css\u2006 \u2006 java\u2006 \u2006 postgresql\u2006 \u2006 git\u2006 \u2006 svn\u2006 \u2006 mobile\xa0testing\u2006 \u2006 selenium\u2006 \u2006 c#\u2006 \u2006 nunit\u2006 \u2006 postman\u2006 \u2006 ci/cd\u2006 \u2006 xpath\u2006 \u2006 selenium\xa0webdriver\u2006 \u2006 manual\xa0testing\u2006 \u2006 scrum\u2006 \u2006 api',
#  'atm monitor.',
#  'atmel',
#  'atomic типы)',
#  'attention to details',
#  'aucotec engineering base',
#  'audio / vibration analysis',
#  'audio unit',
#  'audiokit',
#  'auditd',
#  'aunt',
#  'auth webflux)',
#  'auth)',
#  'authentication)',
#  'authentik',
#  'authorization',
#  'auto hot key',
#  'auto-layout',
#  'auto/manual layout',
#  'autocad',
#  'autodesk 3ds max',
#  'autodesk forge',
#  'autodesk inventor',
#  'autodesk maya',
#  'autodesk vault',
#  'autofac',
#  'autofixture',
#  'autoit',
#  'autolayout (anchors)',
#  'autolayout(ib)',
#  'autolayout.\r\n- вспомогательный стек по дизайну: photoshop',
#  'autolayout/snapkit',
#  'autolayuot',
#  'automapper',
#  'automated testing',
#  'automation expertise',
#  'automation of data collection and processing',
#  'automation qa',
#  'automl',
#  'automotive',
#  'autovalue',
#  'ava',
#  'availability group',
#  'avalonia ui',
#  'avanpost',
#  'avassetexportsession',
#  'avaya',
#  'avaya call management systems',
#  'aveks',
#  'avfoundation',
#  'avfoundation (avplayerlayer',
#  'avocode',
#  'avplayer',
#  'avr',
#  'avvideocompositing',
#  'avvideocompositioninstructionprotocol',
#  'await',
#  'awk',
#  'aws',
#  'aws ( a lot of services )',
#  'aws (ec2',
#  'aws athena',
#  'aws cloud',
#  'aws elasticache (redis)',
#  'aws gcp',
#  'aws glue',
#  'aws lambda',
#  'aws lambda functions',
#  'aws s3',
#  'aws services',
#  'aws sns',
#  'aws | self hosted & bare metal | vm',
#  'aws на профессиональном уровне',
#  'aws: eb',
#  'aws:ес2',
#  'awx',
#  'awx ansible power',
#  'axibase',
#  'axios assyst',
#  'axis',
#  'axure',
#  'axure rp',
#  'azure active directory',
#  'azure ad',
#  'azure architect expert',
#  'azure ci/cd',
#  'azure cloud',
#  'azure devops server',
#  'azure devops services ( git)',
#  'azure devops.',
#  'azure functions',
#  'azure piplines',
#  'azure scale set',
#  'azure service fabric',
#  'azure services',
#  'azure signalr',
#  'azure synapse',
#  'azure.',
#  'azuretfs',
#  'a|b тесты',
#  'aбс',
#  'b2b',
#  'b2b маркетинг',
#  'b2c',
#  'b2c marketing',
#  'b2c продажи',
#  'b2g',
#  'b2g исследования',
#  'babel',
#  'babel.js',
#  'babok',
#  'babylon.js',
#  'back-end',
#  'back-end и front-end программирование (junior)',
#  'back-end: java 8+',
#  'backbonejs',
#  'backend developing',
#  'backend тестирование',
#  'backgroundservice',
#  'backlog',
#  'backlog and feature prioritization',
#  'backuppc',
#  'badi',
#  'bag report',
#  'balanced scorecard',
#  'balsamiq',
#  'balsamiq mockups',
#  ...]

# %%
processed_data = add_features_to_dataframe(data, features)
processed_data['c++'].sum()
# Out:
# ответственность
# ответственность
# ответственность
# ответственность
# обучаемость
# go
# ответственность
# обучаемость
# java
# ответственность
# ответственность
# обучаемость
# ответственность
# ответственность
# ответственность
# ответственность
# ответственность
# ответственность
# обучаемость
# ответственность
# java
# ответственность
# ответственность
# ответственность
# обучаемость
# ответственность
# java
# обучаемость
# обучаемость
# обучаемость
# обучаемость
# ответственность
# обучаемость
# обучаемость
# обучаемость
# ответственность
# ответственность
# ответственность
# ответственность
# обучаемость
# обучаемость
# ответственность
# ответственность
# обучаемость
# обучаемость
# обучаемость
# ответственность
# обучаемость
# обучаемость
# обучаемость
# ответственность
# ответственность
# ответственность
# обучаемость
# ответственность
# ответственность
# обучаемость
# обучаемость
# обучаемость
# java
# java
# 0
